# %% [markdown]
# # Import Libraries

# %%
# Get dataset
# !wget https://raw.githubusercontent.com/GoEco-Living/MachineLearning/refs/heads/main/Dataset/meals.csv
# !wget https://raw.githubusercontent.com/GoEco-Living/MachineLearning/refs/heads/main/Dataset/transport.csv
# Out:
# --2024-12-02 03:43:47--  https://raw.githubusercontent.com/GoEco-Living/MachineLearning/refs/heads/main/Dataset/meals.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8467 (8.3K) [text/plain]
# Saving to: ‘meals.csv’
#
# meals.csv           100%[===================>]   8.27K  --.-KB/s    in 0s
#
# 2024-12-02 03:43:47 (52.0 MB/s) - ‘meals.csv’ saved [8467/8467]
#
# --2024-12-02 03:43:47--  https://raw.githubusercontent.com/GoEco-Living/MachineLearning/refs/heads/main/Dataset/transport.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15386 (15K) [text/plain]
# Saving to: ‘transport.csv’
#
# transport.csv       100%[===================>]  15.03K  --.-KB/s    in 0s
#
# 2024-12-02 03:43:47 (49.1 MB/s) - ‘transport.csv’ saved [15386/15386]

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Processing Data

# %%
# Load dataset
meals_df = pd.read_csv('meals.csv')
transport_df = pd.read_csv('transport.csv')

# %%
meals_df.sample(5)
# Out:
#        Food Item  Carbon kg CO2eq/kg Category
# 57   pomegranate                1.17    Vegan
# 253    porbeagle               11.44     Fish
# 50        tomato                0.91    Vegan
# 6            oat                0.67    Vegan
# 37    watermelon                0.52    Vegan

# %%
# Rename category
for index, row in meals_df.iterrows():
    if row['Category'] in ['fish frozen', 'fish processed', 'shellfish', 'shellfish frozen']:
        meals_df.at[index, 'Category'] = 'Fish'
    else:
        meals_df.at[index, 'Category'] = row['Category']

# %% [markdown]
# # **Meals Model**

# %%
meals_df.sample(5)
# Out:
#                  Food Item  Carbon kg CO2eq/kg    Category
# 305  rabbit meat with bone                4.31        Beef
# 198           zucchini (f)                1.35       Vegan
# 281            tuna in can                2.10        Fish
# 68                chestnut                0.44       Vegan
# 223       cheese semi-hard                8.65  Vegetarian

# %% [markdown]
# ## Create Model

# %%
meals_mapping = {category: idx for idx, category in enumerate(meals_df["Category"].unique())}
meals_df["Category_encoded"] = meals_df["Category"].map(meals_mapping)

# Prepare features and target variable
X = meals_df["Category_encoded"].values.reshape(-1, 1)
y = meals_df["Carbon kg CO2eq/kg"].values.reshape(-1, 1)

# Normalize the target variable (carbon emissions)
scaler = MinMaxScaler()
y_normalized = scaler.fit_transform(y)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_normalized, test_size=0.2, random_state=42)

def create_meal_model():
    meal_input = tf.keras.layers.Input(shape=(1,), name="meal_input")

    meal_embedding = tf.keras.layers.Embedding(input_dim=len(meals_mapping), output_dim=5)(meal_input)
    meal_flatten = tf.keras.layers.Flatten()(meal_embedding)
    dense_1 = tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01))(meal_flatten)

    # Menambahkan Dropout untuk mengurangi overfitting
    dropout_1 = tf.keras.layers.Dropout(0.2)(dense_1)

    dense_2 = tf.keras.layers.Dense(32, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01))(dropout_1)

    # Output untuk emisi karbon
    carbon_output = tf.keras.layers.Dense(1, activation="linear", name="meal_carbon_output")(dense_2)

    # Create and compile the model
    optimizer = tf.keras.optimizers.Adam()

    model = tf.keras.Model(inputs=[meal_input], outputs=[carbon_output])
    model.compile(optimizer=optimizer, loss="mse", metrics=["mae"])

    return model

# %%
meal_model = create_meal_model()
meal_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ meal_input (InputLayer)              │ (None, 1)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, 1, 5)                │              25 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 5)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ meal_carbon_output (Dense)           │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,522 (9.85 KB)
#  Trainable params: 2,522 (9.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train Model

# %%
history = meal_model.fit(X_train, y_train, epochs=100, validation_split=0.6)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5252 - mae: 0.0346 - val_loss: 0.5106 - val_mae: 0.0357
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5000 - mae: 0.0272 - val_loss: 0.4868 - val_mae: 0.0363
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4770 - mae: 0.0283 - val_loss: 0.4641 - val_mae: 0.0318
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4541 - mae: 0.0213 - val_loss: 0.4425 - val_mae: 0.0294
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4330 - mae: 0.0211 - val_loss: 0.4217 - val_mae: 0.0288
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4120 - mae: 0.0189 - val_loss: 0.4017 - val_mae: 0.0288
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3928 - mae: 0.0214 - val_loss: 0.3826 - val_mae: 0.0291
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3730 - mae: 0.0171 - val_loss: 0.3644 - val_mae: 0.0288
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3559 - mae: 0.0227 - val_loss: 0.3469 - val_mae: 0.0295
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3381 - mae: 0.0211 - val_loss: 0.3302 - val_mae: 0.0296
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3218 - mae: 0.0209 - val_loss: 0.3142 - val_mae: 0.0296
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3056 - mae: 0.0188 - val_loss: 0.2990 - val_mae: 0.0295
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2909 - mae: 0.0203 - val_loss: 0.2845 - val_mae: 0.0293
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2762 - mae: 0.0200 - val_loss: 0.2706 - val_mae: 0.0294
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2623 - mae: 0.0194 - val_loss: 0.2574 - val_mae: 0.0293
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2499 - mae: 0.0218 - val_loss: 0.2447 - val_mae: 0.0295
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2367 - mae: 0.0193 - val_loss: 0.2327 - val_mae: 0.0294
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2254 - mae: 0.0217 - val_loss: 0.2212 - val_mae: 0.0296
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2132 - mae: 0.0193 - val_loss: 0.2103 - val_mae: 0.0291
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2024 - mae: 0.0179 - val_loss: 0.1999 - val_mae: 0.0297
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1922 - mae: 0.0187 - val_loss: 0.1899 - val_mae: 0.0297
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1826 - mae: 0.0214 - val_loss: 0.1804 - val_mae: 0.0297
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1731 - mae: 0.0206 - val_loss: 0.1714 - val_mae: 0.0293
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1643 - mae: 0.0198 - val_loss: 0.1628 - val_mae: 0.0291
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1555 - mae: 0.0186 - val_loss: 0.1547 - val_mae: 0.0288
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1476 - mae: 0.0192 - val_loss: 0.1469 - val_mae: 0.0293
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1399 - mae: 0.0206 - val_loss: 0.1395 - val_mae: 0.0299
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1326 - mae: 0.0195 - val_loss: 0.1324 - val_mae: 0.0293
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1254 - mae: 0.0194 - val_loss: 0.1257 - val_mae: 0.0290
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1188 - mae: 0.0189 - val_loss: 0.1194 - val_mae: 0.0294
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1133 - mae: 0.0229 - val_loss: 0.1133 - val_mae: 0.0302
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1071 - mae: 0.0219 - val_loss: 0.1075 - val_mae: 0.0298
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1007 - mae: 0.0185 - val_loss: 0.1021 - val_mae: 0.0288
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0958 - mae: 0.0204 - val_loss: 0.0969 - val_mae: 0.0295
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0901 - mae: 0.0186 - val_loss: 0.0919 - val_mae: 0.0301
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0859 - mae: 0.0216 - val_loss: 0.0872 - val_mae: 0.0303
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0810 - mae: 0.0201 - val_loss: 0.0828 - val_mae: 0.0297
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0766 - mae: 0.0213 - val_loss: 0.0786 - val_mae: 0.0293
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0728 - mae: 0.0224 - val_loss: 0.0745 - val_mae: 0.0297
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0689 - mae: 0.0226 - val_loss: 0.0707 - val_mae: 0.0300
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0645 - mae: 0.0201 - val_loss: 0.0671 - val_mae: 0.0298
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0608 - mae: 0.0196 - val_loss: 0.0637 - val_mae: 0.0295
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0575 - mae: 0.0189 - val_loss: 0.0605 - val_mae: 0.0297
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0543 - mae: 0.0190 - val_loss: 0.0574 - val_mae: 0.0298
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0517 - mae: 0.0237 - val_loss: 0.0544 - val_mae: 0.0310
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0486 - mae: 0.0220 - val_loss: 0.0517 - val_mae: 0.0294
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0454 - mae: 0.0179 - val_loss: 0.0492 - val_mae: 0.0289
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0436 - mae: 0.0212 - val_loss: 0.0466 - val_mae: 0.0304
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0409 - mae: 0.0226 - val_loss: 0.0443 - val_mae: 0.0304
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0381 - mae: 0.0189 - val_loss: 0.0421 - val_mae: 0.0297
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0358 - mae: 0.0181 - val_loss: 0.0400 - val_mae: 0.0302
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0342 - mae: 0.0214 - val_loss: 0.0380 - val_mae: 0.0312
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0322 - mae: 0.0211 - val_loss: 0.0362 - val_mae: 0.0296
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0308 - mae: 0.0218 - val_loss: 0.0345 - val_mae: 0.0296
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0284 - mae: 0.0192 - val_loss: 0.0328 - val_mae: 0.0298
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0273 - mae: 0.0210 - val_loss: 0.0312 - val_mae: 0.0313
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0260 - mae: 0.0248 - val_loss: 0.0298 - val_mae: 0.0308
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0237 - mae: 0.0191 - val_loss: 0.0285 - val_mae: 0.0291
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0226 - mae: 0.0190 - val_loss: 0.0271 - val_mae: 0.0298
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0212 - mae: 0.0194 - val_loss: 0.0258 - val_mae: 0.0312
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0201 - mae: 0.0215 - val_loss: 0.0247 - val_mae: 0.0315
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0193 - mae: 0.0226 - val_loss: 0.0236 - val_mae: 0.0303
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0183 - mae: 0.0228 - val_loss: 0.0226 - val_mae: 0.0296
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0169 - mae: 0.0200 - val_loss: 0.0217 - val_mae: 0.0297
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0157 - mae: 0.0193 - val_loss: 0.0207 - val_mae: 0.0307
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0146 - mae: 0.0200 - val_loss: 0.0198 - val_mae: 0.0317
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0141 - mae: 0.0226 - val_loss: 0.0190 - val_mae: 0.0314
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0138 - mae: 0.0229 - val_loss: 0.0183 - val_mae: 0.0302
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0129 - mae: 0.0216 - val_loss: 0.0176 - val_mae: 0.0305
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0116 - mae: 0.0197 - val_loss: 0.0169 - val_mae: 0.0306
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0112 - mae: 0.0207 - val_loss: 0.0163 - val_mae: 0.0310
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0108 - mae: 0.0219 - val_loss: 0.0157 - val_mae: 0.0311
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0100 - mae: 0.0212 - val_loss: 0.0152 - val_mae: 0.0303
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0103 - mae: 0.0244 - val_loss: 0.0146 - val_mae: 0.0307
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0095 - mae: 0.0239 - val_loss: 0.0141 - val_mae: 0.0307
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0090 - mae: 0.0243 - val_loss: 0.0137 - val_mae: 0.0308
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0078 - mae: 0.0203 - val_loss: 0.0133 - val_mae: 0.0304
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0075 - mae: 0.0216 - val_loss: 0.0128 - val_mae: 0.0315
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0076 - mae: 0.0227 - val_loss: 0.0125 - val_mae: 0.0315
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0073 - mae: 0.0232 - val_loss: 0.0122 - val_mae: 0.0304
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0073 - mae: 0.0236 - val_loss: 0.0118 - val_mae: 0.0305
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0066 - mae: 0.0230 - val_loss: 0.0115 - val_mae: 0.0306
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0060 - mae: 0.0213 - val_loss: 0.0112 - val_mae: 0.0311
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0058 - mae: 0.0227 - val_loss: 0.0109 - val_mae: 0.0316
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0061 - mae: 0.0252 - val_loss: 0.0107 - val_mae: 0.0310
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0052 - mae: 0.0218 - val_loss: 0.0105 - val_mae: 0.0309
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0044 - mae: 0.0189 - val_loss: 0.0103 - val_mae: 0.0305
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mae: 0.0220 - val_loss: 0.0100 - val_mae: 0.0329
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046 - mae: 0.0249 - val_loss: 0.0098 - val_mae: 0.0328
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - mae: 0.0223 - val_loss: 0.0097 - val_mae: 0.0301
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0049 - mae: 0.0236 - val_loss: 0.0095 - val_mae: 0.0308
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mae: 0.0250 - val_loss: 0.0093 - val_mae: 0.0317
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0230 - val_loss: 0.0092 - val_mae: 0.0309
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035 - mae: 0.0192 - val_loss: 0.0091 - val_mae: 0.0304
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - mae: 0.0218 - val_loss: 0.0089 - val_mae: 0.0320
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0033 - mae: 0.0223 - val_loss: 0.0088 - val_mae: 0.0317
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0033 - mae: 0.0218 - val_loss: 0.0087 - val_mae: 0.0313
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0036 - mae: 0.0230 - val_loss: 0.0087 - val_mae: 0.0307
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032 - mae: 0.0223 - val_loss: 0.0085 - val_mae: 0.0309
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0035 - mae: 0.0235 - val_loss: 0.0084 - val_mae: 0.0312

# %%
loss, mae = meal_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss}")
print(f"Test MAE: {mae}")
# Out:
# Test Loss: 0.0029712459072470665
# Test MAE: 0.024862229824066162

# %%
history_data = history.history

# Visualisasi Loss
plt.figure(figsize=(10, 5))

# training loss & validation loss
plt.subplot(1, 2, 1)
plt.plot(history_data['loss'], label='Training Loss')
plt.plot(history_data['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# MAE
plt.subplot(1, 2, 2)
plt.plot(history_data['mae'], label='Training MAE')
plt.plot(history_data['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error (MAE)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(meals_mapping)
# Out:
# {'Vegan': 0, 'Vegetarian': 1, 'Fish': 2, 'Beef': 3, 'Chicken': 4}

# %%
# Menggunakan indeks yang benar sesuai dengan meals_mapping
sample_category = np.array([meals_mapping['Beef']])
# Prediksi dengan model yang telah dilatih
predicted_carbon = meal_model.predict(sample_category)

# De-normalisasi hasil prediksi karbon untuk mendapatkan nilai asli
predicted_carbon_actual = scaler.inverse_transform(predicted_carbon)

print(f"Predicted carbon emission for the food : {predicted_carbon_actual[0][0]} kg CO2eq")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Predicted carbon emission for the food : 5.930556297302246 kg CO2eq

# %%
def recommend_lower_carbon(category_input, model, meals_mapping, scaler):
    # Mengubah kategori input menjadi encoded
    input_index = meals_mapping.get(category_input, None)
    if input_index is None:
        print("Kategori tidak valid.")
        return []

    # Prediksi karbon untuk kategori input
    sample_category = np.array([input_index])
    predicted_carbon = model.predict(sample_category)
    predicted_carbon_actual = scaler.inverse_transform(predicted_carbon)
    user_carbon = predicted_carbon_actual[0][0]

    print(f"Predicted carbon emission for '{category_input}': {user_carbon} kg CO2eq")

    # Menemukan kategori dengan karbon lebih rendah
    lower_carbon_recommendations = []
    for category, index in meals_mapping.items():
        if category != category_input:
            sample_category = np.array([index])
            predicted_carbon = model.predict(sample_category)
            predicted_carbon_actual = scaler.inverse_transform(predicted_carbon)
            carbon_value = predicted_carbon_actual[0][0]

            # Jika karbon lebih rendah, tambahkan ke rekomendasi
            if carbon_value < user_carbon:
                lower_carbon_recommendations.append((category, carbon_value))

    # Sort berdasarkan karbon emisi yang lebih rendah
    lower_carbon_recommendations.sort(key=lambda x: x[1])

    return lower_carbon_recommendations

# Contoh penggunaan
category_input = "Vegetarian"  # Kategori input dari pengguna
lower_carbon_recs = recommend_lower_carbon(category_input, meal_model, meals_mapping, scaler)

# Tampilkan rekomendasi
if lower_carbon_recs:
    print("\nRecommended meals with lower carbon emissions:")
    for rec in lower_carbon_recs:
        print(f"{rec[0]}: {rec[1]:.2f} kg CO2eq")
else:
    print("No meals with lower carbon emissions found.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted carbon emission for 'Vegetarian': 4.853299617767334 kg CO2eq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# Recommended meals with lower carbon emissions:
# Vegan: 1.93 kg CO2eq
# Chicken: 4.62 kg CO2eq

# %%
# Save
meal_model.save('meal_model.h5')
print("Model saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved
